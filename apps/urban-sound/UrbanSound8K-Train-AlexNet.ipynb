# %% [markdown]
# # UrbanSound8K
#
# As described in [Overview & Preprocess](UrbanSound8K-Overview&Preprocess.ipynb) notebook, state of the art accuracy of this dataset is about 73-74% so far.
#
# This notebook tries with AlexNet based model, actually this resulted in better accuracy than MobileNetV2 model.
# This also follows machine learning workflow frame defined by a class [ProjectML](https://raw.githubusercontent.com/daisukelab/project-ml/master/projectml.py) so that it gets clear what is done for this solution.
#
# The UrbanSound8K dataset requires us to make sure executing 10-fold cross validation to get the result, then this notebook repeats 10 cycles to do the cross validation for 10 folds.
#
# ## Result
#
# Mean accuracy of all 10 folds is 0.729, good enough to be close to the SOTA result.

# %%
import sys
sys.path.append('../..')
from lib_train import *
import matplotlib.pyplot as plt
# %matplotlib inline
from ext.projectml import ProjectML
# Out:
# {'sampling_rate': 44100, 'duration': 1, 'hop_length': 347, 'fmin': 20, 'fmax': 22050, 'n_mels': 128, 'n_fft': 2560, 'model': 'mobilenetv2', 'labels': ['dog_bark', 'children_playing', 'car_horn', 'air_conditioner', 'street_music', 'gun_shot', 'siren', 'engine_idling', 'jackhammer', 'drilling'], 'folder': PosixPath('.'), 'n_fold': 1, 'valid_limit': None, 'random_state': 42, 'test_size': 0.01, 'samples_per_file': 5, 'batch_size': 40, 'data_balancing': 'by_generator', 'learning_rate': 0.0001, 'metric_save_ckpt': 'val_acc', 'epochs': 100, 'verbose': 2, 'best_weight_file': 'best_model_weight.h5', 'rt_process_count': 1, 'rt_oversamples': 10, 'pred_ensembles': 10, 'runtime_model_file': 'model/mobilenetv2_fsd2018_41cls.pb', 'label2int': {'dog_bark': 0, 'children_playing': 1, 'car_horn': 2, 'air_conditioner': 3, 'street_music': 4, 'gun_shot': 5, 'siren': 6, 'engine_idling': 7, 'jackhammer': 8, 'drilling': 9}, 'num_classes': 10, 'samples': 44100, 'rt_chunk_samples': 4410, 'mels_onestep_samples': 4410, 'mels_convert_samples': 48510, 'dims': [128, 128, 1], 'metric_save_mode': 'auto', 'logdir': 'logs', 'X_train': 'X_train.npy', 'y_train': 'y_train.npy', 'X_test': 'X_test.npy', 'y_test': 'y_test.npy', 'steps_per_epoch_limit': None}
# Using TensorFlow backend.

# %%
def project_setup(pj):
    """Setup for entire training session."""
    pj.vars.holdout_fold = 0
    pj.results.metrics = []
    pj.prms.model = 'alexnet'
    pj.prms.epochs = 100
    pj.prms.metric_save_ckpt = 'val_acc'
    pj.prms.data_balancing = 'by_generator'
    pj.prms.batch_size = pj.prms.num_classes * 2

def cycle_update_parameter(pj):
    """Update parameter for current fold."""
    print('== Fold {} =='.format(pj.vars.holdout_fold))
    pj.prms.best_weight_file = 'model_weight_%d.h5' % pj.vars.holdout_fold

def cycle_setup_data(pj):
    """Load data for current fold."""
    X_train = []
    y_train = []
    for fold in range(pj.dataset_policy.cv_folds):
        if pj.vars.holdout_fold == fold:
            continue
        X_train.extend(np.load('X_fold%d.npy' % (fold+1)))
        y_train.extend(np.load('y_fold%d.npy' % (fold+1)))
    pj.vars.X_train = np.array(X_train)
    pj.vars.X_valid = np.load('X_fold%d.npy' % (pj.vars.holdout_fold+1))
    pj.vars.y_train = keras.utils.to_categorical(y_train)
    pj.vars.y_valid = keras.utils.to_categorical(np.load('y_fold%d.npy' % (pj.vars.holdout_fold+1)))
    # Normalize
    samplewise_normalize_audio_X(pj.vars.X_train)
    samplewise_normalize_audio_X(pj.vars.X_valid)

def cycle_train_model(pj):
    """Train model for current fold."""
    _, model = train_classifier(pj.prms, fold=0,
                                dataset=[pj.vars.X_train,
                                         pj.vars.y_train,
                                         pj.vars.X_valid,
                                         pj.vars.y_valid],
                                model=None)
    pj.vars.training_vars = [model]

def cycle_evaluate(pj):
    """Evaluate a metric."""
    model = pj.vars.training_vars[0]
    model.load_weights(pj.prms.best_weight_file)
    pj.results.metrics.append(evaluate_model(pj.prms, model,
                                             pj.vars.X_valid, pj.vars.y_valid))

def cycle_update_policy(pj):
    """Check for completion - this is policy for this app."""
    pj.vars.holdout_fold += 1
    if pj.vars.holdout_fold >= pj.dataset_policy.cv_folds:
        return False # finished all folds, no need to continue
    return True # continue cycles

def summarize_total_performance(pj):
    """Summarize total performance."""
    df = summarize_metrics_history(pj.results.metrics)
    print('Final acc = ', df.accuracy.mean())

#
project = ProjectML(
    setup_fn=project_setup,
    cycle_update_parameter_fn=cycle_update_parameter,
    cycle_setup_data_fn=cycle_setup_data,
    cycle_train_model_fn=cycle_train_model,
    cycle_evaluate_fn=cycle_evaluate,
    cycle_update_policy_fn=cycle_update_policy,
    summarize_total_fn=summarize_total_performance,
    dataset_policy={'cv_folds': 10},
    parameters=conf
)

project.run()
# Out:
# Dataset policy: {'cv_folds': 10}
# Training policy: {}
# Parameters: {'sampling_rate': 44100, 'duration': 1, 'hop_length': 347, 'fmin': 20, 'fmax': 22050, 'n_mels': 128, 'n_fft': 2560, 'model': 'alexnet', 'labels': ['dog_bark', 'children_playing', 'car_horn', 'air_conditioner', 'street_music', 'gun_shot', 'siren', 'engine_idling', 'jackhammer', 'drilling'], 'folder': PosixPath('.'), 'n_fold': 1, 'valid_limit': None, 'random_state': 42, 'test_size': 0.01, 'samples_per_file': 5, 'batch_size': 20, 'data_balancing': 'by_generator', 'learning_rate': 0.0001, 'metric_save_ckpt': 'val_acc', 'epochs': 100, 'verbose': 2, 'best_weight_file': 'best_model_weight.h5', 'rt_process_count': 1, 'rt_oversamples': 10, 'pred_ensembles': 10, 'runtime_model_file': 'model/mobilenetv2_fsd2018_41cls.pb', 'label2int': {'dog_bark': 0, 'children_playing': 1, 'car_horn': 2, 'air_conditioner': 3, 'street_music': 4, 'gun_shot': 5, 'siren': 6, 'engine_idling': 7, 'jackhammer': 8, 'drilling': 9}, 'num_classes': 10, 'samples': 44100, 'rt_chunk_samples': 4410, 'mels_onestep_samples': 4410, 'mels_convert_samples': 48510, 'dims': [128, 128, 1], 'metric_save_mode': 'auto', 'logdir': 'logs', 'X_train': 'X_train.npy', 'y_train': 'y_train.npy', 'X_test': 'X_test.npy', 'y_test': 'y_test.npy', 'steps_per_epoch_limit': None}
# Variables: 2 variables
#
# [Cycle #0]
# == Fold 0 ==
#  Dataset is not balanced so far, conf.data_balancing = by_generator
#  Using normal data generator, with class balancing
#  train_steps_per_epoch, valid_steps_per_epoch = 1964, 218
# Model: AlexNet based
# Epoch 1/100
#  - 35s - loss: 1.9524 - acc: 0.3251 - val_loss: 1.5109 - val_acc: 0.4994
#
# Epoch 00001: val_acc improved from -inf to 0.49943, saving model to model_weight_0.h5
# Epoch 2/100
#  - 34s - loss: 1.5338 - acc: 0.5083 - val_loss: 2.5566 - val_acc: 0.3677
#
# Epoch 00002: val_acc did not improve from 0.49943
# Epoch 3/100
#  - 34s - loss: 1.3315 - acc: 0.5927 - val_loss: 1.8109 - val_acc: 0.5148
#
# Epoch 00003: val_acc improved from 0.49943 to 0.51478, saving model to model_weight_0.h5
# Epoch 4/100
#  - 34s - loss: 1.1973 - acc: 0.6496 - val_loss: 1.9389 - val_acc: 0.4953
#
# Epoch 00004: val_acc did not improve from 0.51478
# Epoch 5/100
#  - 34s - loss: 1.1296 - acc: 0.6750 - val_loss: 1.8834 - val_acc: 0.5645
#
# Epoch 00005: val_acc improved from 0.51478 to 0.56449, saving model to model_weight_0.h5
# Epoch 6/100
#  - 34s - loss: 1.0574 - acc: 0.7087 - val_loss: 1.6094 - val_acc: 0.5565
#
# Epoch 00006: val_acc did not improve from 0.56449
# Epoch 7/100
#  - 34s - loss: 1.0072 - acc: 0.7260 - val_loss: 1.6940 - val_acc: 0.5567
#
# Epoch 00007: val_acc did not improve from 0.56449
# Epoch 8/100
#  - 34s - loss: 0.9764 - acc: 0.7407 - val_loss: 1.7384 - val_acc: 0.5510
#
# Epoch 00008: val_acc did not improve from 0.56449
# Epoch 9/100
#  - 34s - loss: 0.9432 - acc: 0.7548 - val_loss: 2.2170 - val_acc: 0.5038
#
# Epoch 00009: val_acc did not improve from 0.56449
# Epoch 10/100
#  - 34s - loss: 0.9144 - acc: 0.7658 - val_loss: 1.7251 - val_acc: 0.5837
#
# Epoch 00010: val_acc improved from 0.56449 to 0.58373, saving model to model_weight_0.h5
# Epoch 11/100
#  - 34s - loss: 0.8980 - acc: 0.7702 - val_loss: 1.6422 - val_acc: 0.6073
#
# Epoch 00011: val_acc improved from 0.58373 to 0.60733, saving model to model_weight_0.h5
# Epoch 12/100
#  - 34s - loss: 0.8770 - acc: 0.7805 - val_loss: 1.6496 - val_acc: 0.6071
#
# Epoch 00012: val_acc did not improve from 0.60733
# Epoch 13/100
#  - 34s - loss: 0.8579 - acc: 0.7874 - val_loss: 1.4406 - val_acc: 0.6685
#
# Epoch 00013: val_acc improved from 0.60733 to 0.66850, saving model to model_weight_0.h5
# Epoch 14/100
#  - 34s - loss: 0.8489 - acc: 0.7895 - val_loss: 1.6948 - val_acc: 0.6291
#
# Epoch 00014: val_acc did not improve from 0.66850
# Epoch 15/100
#  - 34s - loss: 0.8349 - acc: 0.7970 - val_loss: 1.7038 - val_acc: 0.6490
#
# Epoch 00015: val_acc did not improve from 0.66850
# Epoch 16/100
#  - 34s - loss: 0.8207 - acc: 0.7999 - val_loss: 2.4322 - val_acc: 0.5359
#
# Epoch 00016: val_acc did not improve from 0.66850
# Epoch 17/100
#  - 34s - loss: 0.8134 - acc: 0.8021 - val_loss: 2.0119 - val_acc: 0.6195
#
# Epoch 00017: val_acc did not improve from 0.66850
# Epoch 18/100
#  - 34s - loss: 0.7949 - acc: 0.8113 - val_loss: 1.8700 - val_acc: 0.6394
#
# Epoch 00018: val_acc did not improve from 0.66850
# Epoch 19/100
#  - 34s - loss: 0.8008 - acc: 0.8073 - val_loss: 1.7906 - val_acc: 0.6314
#
# Epoch 00019: val_acc did not improve from 0.66850
# Epoch 20/100
#  - 34s - loss: 0.7830 - acc: 0.8130 - val_loss: 2.4333 - val_acc: 0.6472
#
# Epoch 00020: val_acc did not improve from 0.66850
# Epoch 21/100
#  - 34s - loss: 0.7757 - acc: 0.8173 - val_loss: 1.9890 - val_acc: 0.6440
#
# Epoch 00021: val_acc did not improve from 0.66850
# Epoch 22/100
#  - 34s - loss: 0.7704 - acc: 0.8161 - val_loss: 2.1035 - val_acc: 0.5450
#
# Epoch 00022: val_acc did not improve from 0.66850
# Epoch 23/100
#  - 34s - loss: 0.7615 - acc: 0.8212 - val_loss: 1.8078 - val_acc: 0.6300
#
# Epoch 00023: val_acc did not improve from 0.66850
# Epoch 24/100
#  - 34s - loss: 0.7589 - acc: 0.8231 - val_loss: 2.0894 - val_acc: 0.6192
#
# Epoch 00024: val_acc did not improve from 0.66850
# Epoch 25/100
#  - 34s - loss: 0.7528 - acc: 0.8283 - val_loss: 2.1558 - val_acc: 0.6002
#
# Epoch 00025: val_acc did not improve from 0.66850
# Epoch 26/100
#  - 34s - loss: 0.7437 - acc: 0.8332 - val_loss: 1.8420 - val_acc: 0.5828
#
# Epoch 00026: val_acc did not improve from 0.66850
# Epoch 27/100
#  - 34s - loss: 0.7420 - acc: 0.8310 - val_loss: 2.1203 - val_acc: 0.5732
#
# Epoch 00027: val_acc did not improve from 0.66850
# Epoch 28/100
#  - 34s - loss: 0.7368 - acc: 0.8328 - val_loss: 2.0365 - val_acc: 0.5872
#
# Epoch 00028: val_acc did not improve from 0.66850
# Epoch 29/100
#  - 34s - loss: 0.7292 - acc: 0.8339 - val_loss: 2.2847 - val_acc: 0.4674
#
# Epoch 00029: val_acc did not improve from 0.66850
# Epoch 30/100
#  - 34s - loss: 0.7222 - acc: 0.8378 - val_loss: 2.1142 - val_acc: 0.6089
#
# Epoch 00030: val_acc did not improve from 0.66850
# Epoch 31/100
#  - 34s - loss: 0.7251 - acc: 0.8383 - val_loss: 2.5252 - val_acc: 0.6575
#
# Epoch 00031: val_acc did not improve from 0.66850
# Epoch 32/100
#  - 34s - loss: 0.7178 - acc: 0.8393 - val_loss: 2.6075 - val_acc: 0.5979
#
# Epoch 00032: val_acc did not improve from 0.66850
# Epoch 33/100
#  - 34s - loss: 0.7208 - acc: 0.8412 - val_loss: 2.0186 - val_acc: 0.5966
#
# Epoch 00033: val_acc did not improve from 0.66850
# Epoch 34/100
#  - 34s - loss: 0.7070 - acc: 0.8466 - val_loss: 2.0485 - val_acc: 0.6355
#
# Epoch 00034: val_acc did not improve from 0.66850
# Epoch 35/100
#  - 34s - loss: 0.7061 - acc: 0.8453 - val_loss: 2.1693 - val_acc: 0.5888
#
# Epoch 00035: val_acc did not improve from 0.66850
# Epoch 36/100
#  - 34s - loss: 0.7001 - acc: 0.8490 - val_loss: 1.7453 - val_acc: 0.6351
#
# Epoch 00036: val_acc did not improve from 0.66850
# Epoch 37/100
#  - 34s - loss: 0.7018 - acc: 0.8457 - val_loss: 2.5086 - val_acc: 0.5805
#
# Epoch 00037: val_acc did not improve from 0.66850
# Epoch 38/100
#  - 34s - loss: 0.7026 - acc: 0.8430 - val_loss: 2.0415 - val_acc: 0.6325
#
# Epoch 00038: val_acc did not improve from 0.66850
# Epoch 39/100
#  - 34s - loss: 0.6956 - acc: 0.8481 - val_loss: 1.9043 - val_acc: 0.6254
#
# Epoch 00039: val_acc did not improve from 0.66850
# Epoch 40/100
#  - 34s - loss: 0.6910 - acc: 0.8498 - val_loss: 2.4192 - val_acc: 0.6449
#
# Epoch 00040: val_acc did not improve from 0.66850
# Epoch 41/100
#  - 34s - loss: 0.6884 - acc: 0.8535 - val_loss: 2.0864 - val_acc: 0.6332
#
# Epoch 00041: val_acc did not improve from 0.66850
# Epoch 42/100
#  - 34s - loss: 0.6873 - acc: 0.8498 - val_loss: 2.0934 - val_acc: 0.6353
#
# Epoch 00042: val_acc did not improve from 0.66850
# Epoch 43/100
#  - 34s - loss: 0.6838 - acc: 0.8518 - val_loss: 2.7344 - val_acc: 0.5223
#
# Epoch 00043: val_acc did not improve from 0.66850
# Epoch 44/100
#  - 34s - loss: 0.6789 - acc: 0.8548 - val_loss: 2.2144 - val_acc: 0.6667
#
# Epoch 00044: val_acc did not improve from 0.66850
# Epoch 45/100
#  - 34s - loss: 0.6766 - acc: 0.8555 - val_loss: 2.2156 - val_acc: 0.6300
#
# Epoch 00045: val_acc did not improve from 0.66850
# Epoch 46/100
#  - 34s - loss: 0.6789 - acc: 0.8560 - val_loss: 2.5118 - val_acc: 0.6312
#
# Epoch 00046: val_acc did not improve from 0.66850
# Epoch 47/100
#  - 34s - loss: 0.6758 - acc: 0.8594 - val_loss: 2.3528 - val_acc: 0.6488
#
# Epoch 00047: val_acc did not improve from 0.66850
# Epoch 48/100
#  - 34s - loss: 0.6698 - acc: 0.8595 - val_loss: 2.2098 - val_acc: 0.6268
#
# Epoch 00048: val_acc did not improve from 0.66850
# Epoch 49/100
#  - 34s - loss: 0.6682 - acc: 0.8576 - val_loss: 2.0863 - val_acc: 0.6458
#
# Epoch 00049: val_acc did not improve from 0.66850
# Epoch 50/100
#  - 34s - loss: 0.6710 - acc: 0.8602 - val_loss: 2.9279 - val_acc: 0.6080
#
# Epoch 00050: val_acc did not improve from 0.66850
# Epoch 51/100
#  - 34s - loss: 0.6673 - acc: 0.8605 - val_loss: 2.4947 - val_acc: 0.6252
#
# Epoch 00051: val_acc did not improve from 0.66850
# Epoch 52/100
#  - 34s - loss: 0.6679 - acc: 0.8602 - val_loss: 2.2481 - val_acc: 0.6470
#
# Epoch 00052: val_acc did not improve from 0.66850
# Epoch 53/100
#  - 34s - loss: 0.6571 - acc: 0.8636 - val_loss: 2.7778 - val_acc: 0.6573
#
# Epoch 00053: val_acc did not improve from 0.66850
# Epoch 54/100
#  - 34s - loss: 0.6591 - acc: 0.8629 - val_loss: 3.2990 - val_acc: 0.6062
#
# Epoch 00054: val_acc did not improve from 0.66850
# Epoch 55/100
#  - 34s - loss: 0.6602 - acc: 0.8624 - val_loss: 2.2464 - val_acc: 0.6770
#
# Epoch 00055: val_acc improved from 0.66850 to 0.67698, saving model to model_weight_0.h5
# Epoch 56/100
#  - 34s - loss: 0.6573 - acc: 0.8648 - val_loss: 2.2264 - val_acc: 0.6238
#
# Epoch 00056: val_acc did not improve from 0.67698
# Epoch 57/100
#  - 34s - loss: 0.6545 - acc: 0.8668 - val_loss: 2.5808 - val_acc: 0.5979
#
# Epoch 00057: val_acc did not improve from 0.67698
# Epoch 58/100
#  - 34s - loss: 0.6543 - acc: 0.8648 - val_loss: 3.6379 - val_acc: 0.5636
#
# Epoch 00058: val_acc did not improve from 0.67698
# Epoch 59/100
#  - 34s - loss: 0.6556 - acc: 0.8638 - val_loss: 2.8279 - val_acc: 0.6353
#
# Epoch 00059: val_acc did not improve from 0.67698
# Epoch 60/100
#  - 34s - loss: 0.6478 - acc: 0.8649 - val_loss: 2.3089 - val_acc: 0.6628
#
# Epoch 00060: val_acc did not improve from 0.67698
# Epoch 61/100
#  - 34s - loss: 0.6517 - acc: 0.8668 - val_loss: 2.3933 - val_acc: 0.6641
#
# Epoch 00061: val_acc did not improve from 0.67698
# Epoch 62/100
#  - 34s - loss: 0.6466 - acc: 0.8686 - val_loss: 2.9677 - val_acc: 0.5407
#
# Epoch 00062: val_acc did not improve from 0.67698
# Epoch 63/100
#  - 34s - loss: 0.6474 - acc: 0.8666 - val_loss: 2.4601 - val_acc: 0.5207
#
# Epoch 00063: val_acc did not improve from 0.67698
# Epoch 64/100
#  - 34s - loss: 0.6501 - acc: 0.8684 - val_loss: 2.1630 - val_acc: 0.5769
#
# Epoch 00064: val_acc did not improve from 0.67698
# Epoch 65/100
#  - 34s - loss: 0.6444 - acc: 0.8678 - val_loss: 2.4078 - val_acc: 0.6651
#
# Epoch 00065: val_acc did not improve from 0.67698
# Epoch 66/100
#  - 34s - loss: 0.6409 - acc: 0.8702 - val_loss: 2.3924 - val_acc: 0.5775
#
# Epoch 00066: val_acc did not improve from 0.67698
# Epoch 67/100
#  - 34s - loss: 0.6405 - acc: 0.8742 - val_loss: 2.0741 - val_acc: 0.6181
#
# Epoch 00067: val_acc did not improve from 0.67698
# Epoch 68/100
#  - 34s - loss: 0.6408 - acc: 0.8707 - val_loss: 2.8566 - val_acc: 0.6373
#
# Epoch 00068: val_acc did not improve from 0.67698
# Epoch 69/100
#  - 34s - loss: 0.6438 - acc: 0.8696 - val_loss: 2.1521 - val_acc: 0.6548
#
# Epoch 00069: val_acc did not improve from 0.67698
# Epoch 70/100
#  - 34s - loss: 0.6363 - acc: 0.8723 - val_loss: 2.6778 - val_acc: 0.6367
#
# Epoch 00070: val_acc did not improve from 0.67698
# Epoch 71/100
#  - 34s - loss: 0.6373 - acc: 0.8712 - val_loss: 2.5235 - val_acc: 0.6493
#
# Epoch 00071: val_acc did not improve from 0.67698
# Epoch 72/100
#  - 34s - loss: 0.6379 - acc: 0.8697 - val_loss: 2.5969 - val_acc: 0.6376
#
# Epoch 00072: val_acc did not improve from 0.67698
# Epoch 73/100
#  - 34s - loss: 0.6316 - acc: 0.8752 - val_loss: 2.6046 - val_acc: 0.6568
#
# Epoch 00073: val_acc did not improve from 0.67698
# Epoch 74/100
#  - 34s - loss: 0.6350 - acc: 0.8714 - val_loss: 2.5096 - val_acc: 0.6772
#
# Epoch 00074: val_acc improved from 0.67698 to 0.67721, saving model to model_weight_0.h5
# Epoch 75/100
#  - 34s - loss: 0.6331 - acc: 0.8730 - val_loss: 2.2272 - val_acc: 0.6664
#
# Epoch 00075: val_acc did not improve from 0.67721
# Epoch 76/100
#  - 34s - loss: 0.6326 - acc: 0.8735 - val_loss: 2.7344 - val_acc: 0.6449
#
# Epoch 00076: val_acc did not improve from 0.67721
# Epoch 77/100
#  - 34s - loss: 0.6324 - acc: 0.8732 - val_loss: 2.3167 - val_acc: 0.6680
#
# Epoch 00077: val_acc did not improve from 0.67721
# Epoch 78/100
#  - 34s - loss: 0.6287 - acc: 0.8778 - val_loss: 2.7777 - val_acc: 0.6323
#
# Epoch 00078: val_acc did not improve from 0.67721
# Epoch 79/100
#  - 34s - loss: 0.6317 - acc: 0.8776 - val_loss: 2.6313 - val_acc: 0.6069
#
# Epoch 00079: val_acc did not improve from 0.67721
# Epoch 80/100
#  - 34s - loss: 0.6261 - acc: 0.8742 - val_loss: 3.0812 - val_acc: 0.5938
#
# Epoch 00080: val_acc did not improve from 0.67721
# Epoch 81/100
#  - 34s - loss: 0.6307 - acc: 0.8747 - val_loss: 2.6845 - val_acc: 0.5890
#
# Epoch 00081: val_acc did not improve from 0.67721
# Epoch 82/100
#  - 34s - loss: 0.6285 - acc: 0.8732 - val_loss: 2.9735 - val_acc: 0.6481
#
# Epoch 00082: val_acc did not improve from 0.67721
# Epoch 83/100
#  - 34s - loss: 0.6243 - acc: 0.8771 - val_loss: 2.7313 - val_acc: 0.5668
#
# Epoch 00083: val_acc did not improve from 0.67721
# Epoch 84/100
#  - 34s - loss: 0.6261 - acc: 0.8785 - val_loss: 2.4731 - val_acc: 0.6593
#
# Epoch 00084: val_acc did not improve from 0.67721
# Epoch 85/100
#  - 34s - loss: 0.6236 - acc: 0.8765 - val_loss: 2.7558 - val_acc: 0.6584
#
# Epoch 00085: val_acc did not improve from 0.67721
# Epoch 86/100
#  - 34s - loss: 0.6227 - acc: 0.8817 - val_loss: 2.6897 - val_acc: 0.6312
#
# Epoch 00086: val_acc did not improve from 0.67721
# Epoch 87/100
#  - 34s - loss: 0.6232 - acc: 0.8766 - val_loss: 3.1608 - val_acc: 0.6156
#
# Epoch 00087: val_acc did not improve from 0.67721
# Epoch 88/100
#  - 34s - loss: 0.6222 - acc: 0.8792 - val_loss: 2.7941 - val_acc: 0.6438
#
# Epoch 00088: val_acc did not improve from 0.67721
# Epoch 89/100
#  - 34s - loss: 0.6228 - acc: 0.8777 - val_loss: 2.9322 - val_acc: 0.6314
#
# Epoch 00089: val_acc did not improve from 0.67721
# Epoch 90/100
#  - 34s - loss: 0.6202 - acc: 0.8825 - val_loss: 2.5531 - val_acc: 0.5956
#
# Epoch 00090: val_acc did not improve from 0.67721
# Epoch 91/100
#  - 34s - loss: 0.6224 - acc: 0.8788 - val_loss: 3.0112 - val_acc: 0.6101
#
# Epoch 00091: val_acc did not improve from 0.67721
# Epoch 92/100
#  - 34s - loss: 0.6189 - acc: 0.8810 - val_loss: 2.0706 - val_acc: 0.6236
#
# Epoch 00092: val_acc did not improve from 0.67721
# Epoch 93/100
#  - 34s - loss: 0.6183 - acc: 0.8772 - val_loss: 2.8369 - val_acc: 0.5741
#
# Epoch 00093: val_acc did not improve from 0.67721
# Epoch 94/100
#  - 34s - loss: 0.6178 - acc: 0.8817 - val_loss: 2.1046 - val_acc: 0.6296
#
# Epoch 00094: val_acc did not improve from 0.67721
# Epoch 95/100
#  - 34s - loss: 0.6167 - acc: 0.8767 - val_loss: 2.8640 - val_acc: 0.5908
#
# Epoch 00095: val_acc did not improve from 0.67721
# Epoch 96/100
#  - 34s - loss: 0.6160 - acc: 0.8820 - val_loss: 2.6525 - val_acc: 0.6612
#
# Epoch 00096: val_acc did not improve from 0.67721
# Epoch 97/100
#  - 34s - loss: 0.6169 - acc: 0.8809 - val_loss: 3.0901 - val_acc: 0.6554
#
# Epoch 00097: val_acc did not improve from 0.67721
# Epoch 98/100
#  - 34s - loss: 0.6158 - acc: 0.8834 - val_loss: 2.3381 - val_acc: 0.6683
#
# Epoch 00098: val_acc did not improve from 0.67721
# Epoch 99/100
#  - 34s - loss: 0.6124 - acc: 0.8823 - val_loss: 2.3244 - val_acc: 0.6518
#
# Epoch 00099: val_acc did not improve from 0.67721
# Epoch 100/100
#  - 34s - loss: 0.6124 - acc: 0.8832 - val_loss: 2.5739 - val_acc: 0.6655
#
# Epoch 00100: val_acc did not improve from 0.67721
# F1/Recall/Precision/Accuracy = 0.6562/0.6772/0.6807/0.6772
# Ensemble F1/Recall/Precision/Accuracy = 0.6775/0.6999/0.7031/0.6999
# Finished cycle #1.
#
#
# [Cycle #1]
# == Fold 1 ==
#  Dataset is not balanced so far, conf.data_balancing = by_generator
#  Using normal data generator, with class balancing
#  train_steps_per_epoch, valid_steps_per_epoch = 1961, 222
# Model: AlexNet based
# Epoch 1/100
#  - 35s - loss: 1.9467 - acc: 0.3296 - val_loss: 2.9432 - val_acc: 0.2858
#
# Epoch 00001: val_acc improved from -inf to 0.28581, saving model to model_weight_1.h5
# Epoch 2/100
#  - 34s - loss: 1.5392 - acc: 0.4990 - val_loss: 1.8810 - val_acc: 0.4410
#
# Epoch 00002: val_acc improved from 0.28581 to 0.44099, saving model to model_weight_1.h5
# Epoch 3/100
#  - 34s - loss: 1.3466 - acc: 0.5813 - val_loss: 1.9949 - val_acc: 0.4577
#
# Epoch 00003: val_acc improved from 0.44099 to 0.45766, saving model to model_weight_1.h5
# Epoch 4/100
#  - 34s - loss: 1.2146 - acc: 0.6345 - val_loss: 2.0028 - val_acc: 0.5840
#
# Epoch 00004: val_acc improved from 0.45766 to 0.58401, saving model to model_weight_1.h5
# Epoch 5/100
#  - 34s - loss: 1.1281 - acc: 0.6717 - val_loss: 1.5463 - val_acc: 0.6108
#
# Epoch 00005: val_acc improved from 0.58401 to 0.61081, saving model to model_weight_1.h5
# Epoch 6/100
#  - 34s - loss: 1.0713 - acc: 0.7035 - val_loss: 1.8851 - val_acc: 0.5617
#
# Epoch 00006: val_acc did not improve from 0.61081
# Epoch 7/100
#  - 35s - loss: 1.0116 - acc: 0.7245 - val_loss: 2.8107 - val_acc: 0.4599
#
# Epoch 00007: val_acc did not improve from 0.61081
# Epoch 8/100
#  - 34s - loss: 0.9747 - acc: 0.7387 - val_loss: 1.7290 - val_acc: 0.5811
#
# Epoch 00008: val_acc did not improve from 0.61081
# Epoch 9/100
#  - 34s - loss: 0.9502 - acc: 0.7501 - val_loss: 1.6021 - val_acc: 0.5363
#
# Epoch 00009: val_acc did not improve from 0.61081
# Epoch 10/100
#  - 34s - loss: 0.9195 - acc: 0.7598 - val_loss: 2.0605 - val_acc: 0.4723
#
# Epoch 00010: val_acc did not improve from 0.61081
# Epoch 11/100
#  - 34s - loss: 0.9013 - acc: 0.7675 - val_loss: 1.8053 - val_acc: 0.5971
#
# Epoch 00011: val_acc did not improve from 0.61081
# Epoch 12/100
#  - 34s - loss: 0.8791 - acc: 0.7776 - val_loss: 1.4365 - val_acc: 0.6133
#
# Epoch 00012: val_acc improved from 0.61081 to 0.61329, saving model to model_weight_1.h5
# Epoch 13/100
#  - 34s - loss: 0.8647 - acc: 0.7833 - val_loss: 1.5293 - val_acc: 0.6234
#
# Epoch 00013: val_acc improved from 0.61329 to 0.62342, saving model to model_weight_1.h5
# Epoch 14/100
#  - 34s - loss: 0.8492 - acc: 0.7868 - val_loss: 2.8798 - val_acc: 0.4957
#
# Epoch 00014: val_acc did not improve from 0.62342
# Epoch 15/100
#  - 34s - loss: 0.8312 - acc: 0.7942 - val_loss: 2.4612 - val_acc: 0.5482
#
# Epoch 00015: val_acc did not improve from 0.62342
# Epoch 16/100
#  - 34s - loss: 0.8255 - acc: 0.7976 - val_loss: 3.1243 - val_acc: 0.5083
#
# Epoch 00016: val_acc did not improve from 0.62342
# Epoch 17/100
#  - 35s - loss: 0.8102 - acc: 0.8037 - val_loss: 1.2905 - val_acc: 0.6435
#
# Epoch 00017: val_acc improved from 0.62342 to 0.64347, saving model to model_weight_1.h5
# Epoch 18/100
#  - 34s - loss: 0.8023 - acc: 0.8094 - val_loss: 2.0085 - val_acc: 0.6363
#
# Epoch 00018: val_acc did not improve from 0.64347
# Epoch 19/100
#  - 34s - loss: 0.7969 - acc: 0.8088 - val_loss: 2.2388 - val_acc: 0.6207
#
# Epoch 00019: val_acc did not improve from 0.64347
# Epoch 20/100
#  - 34s - loss: 0.7882 - acc: 0.8145 - val_loss: 1.6776 - val_acc: 0.6498
#
# Epoch 00020: val_acc improved from 0.64347 to 0.64977, saving model to model_weight_1.h5
# Epoch 21/100
#  - 34s - loss: 0.7772 - acc: 0.8142 - val_loss: 1.9990 - val_acc: 0.6306
#
# Epoch 00021: val_acc did not improve from 0.64977
# Epoch 22/100
#  - 34s - loss: 0.7644 - acc: 0.8180 - val_loss: 1.8107 - val_acc: 0.6637
#
# Epoch 00022: val_acc improved from 0.64977 to 0.66374, saving model to model_weight_1.h5
# Epoch 23/100
#  - 34s - loss: 0.7617 - acc: 0.8240 - val_loss: 1.7263 - val_acc: 0.5840
#
# Epoch 00023: val_acc did not improve from 0.66374
# Epoch 24/100
#  - 34s - loss: 0.7619 - acc: 0.8269 - val_loss: 2.4540 - val_acc: 0.5509
#
# Epoch 00024: val_acc did not improve from 0.66374
# Epoch 25/100
#  - 34s - loss: 0.7514 - acc: 0.8267 - val_loss: 1.7546 - val_acc: 0.5534
#
# Epoch 00025: val_acc did not improve from 0.66374
# Epoch 26/100
#  - 34s - loss: 0.7445 - acc: 0.8281 - val_loss: 2.7154 - val_acc: 0.5070
#
# Epoch 00026: val_acc did not improve from 0.66374
# Epoch 27/100
#  - 34s - loss: 0.7395 - acc: 0.8301 - val_loss: 2.1168 - val_acc: 0.5489
#
# Epoch 00027: val_acc did not improve from 0.66374
# Epoch 28/100
#  - 34s - loss: 0.7334 - acc: 0.8327 - val_loss: 2.6188 - val_acc: 0.5842
#
# Epoch 00028: val_acc did not improve from 0.66374
# Epoch 29/100
#  - 35s - loss: 0.7305 - acc: 0.8317 - val_loss: 3.5969 - val_acc: 0.5660
#
# Epoch 00029: val_acc did not improve from 0.66374
# Epoch 30/100
#  - 35s - loss: 0.7238 - acc: 0.8358 - val_loss: 1.9939 - val_acc: 0.6214
#
# Epoch 00030: val_acc did not improve from 0.66374
# Epoch 31/100
#  - 35s - loss: 0.7201 - acc: 0.8378 - val_loss: 2.7271 - val_acc: 0.5847
#
# Epoch 00031: val_acc did not improve from 0.66374
# Epoch 32/100
#  - 35s - loss: 0.7191 - acc: 0.8388 - val_loss: 2.2325 - val_acc: 0.6209
#
# Epoch 00032: val_acc did not improve from 0.66374
# Epoch 33/100
#  - 35s - loss: 0.7124 - acc: 0.8390 - val_loss: 2.4266 - val_acc: 0.6257
#
# Epoch 00033: val_acc did not improve from 0.66374
# Epoch 34/100
#  - 35s - loss: 0.7035 - acc: 0.8458 - val_loss: 2.4356 - val_acc: 0.5505
#
# Epoch 00034: val_acc did not improve from 0.66374
# Epoch 35/100
#  - 35s - loss: 0.7112 - acc: 0.8429 - val_loss: 2.9136 - val_acc: 0.5608
#
# Epoch 00035: val_acc did not improve from 0.66374
# Epoch 36/100
#  - 35s - loss: 0.7036 - acc: 0.8466 - val_loss: 3.9852 - val_acc: 0.4975
#
# Epoch 00036: val_acc did not improve from 0.66374
# Epoch 37/100
#  - 35s - loss: 0.6987 - acc: 0.8450 - val_loss: 2.4129 - val_acc: 0.5685
#
# Epoch 00037: val_acc did not improve from 0.66374
# Epoch 38/100
#  - 34s - loss: 0.6953 - acc: 0.8488 - val_loss: 1.7939 - val_acc: 0.6216
#
# Epoch 00038: val_acc did not improve from 0.66374
# Epoch 39/100
#  - 35s - loss: 0.6933 - acc: 0.8459 - val_loss: 2.3909 - val_acc: 0.6399
#
# Epoch 00039: val_acc did not improve from 0.66374
# Epoch 40/100
#  - 35s - loss: 0.6903 - acc: 0.8476 - val_loss: 1.8860 - val_acc: 0.6137
#
# Epoch 00040: val_acc did not improve from 0.66374
# Epoch 41/100
#  - 35s - loss: 0.6844 - acc: 0.8530 - val_loss: 3.6377 - val_acc: 0.5241
#
# Epoch 00041: val_acc did not improve from 0.66374
# Epoch 42/100
#  - 34s - loss: 0.6842 - acc: 0.8503 - val_loss: 2.5194 - val_acc: 0.5989
#
# Epoch 00042: val_acc did not improve from 0.66374
# Epoch 43/100
#  - 35s - loss: 0.6813 - acc: 0.8549 - val_loss: 1.7649 - val_acc: 0.6086
#
# Epoch 00043: val_acc did not improve from 0.66374
# Epoch 44/100
#  - 35s - loss: 0.6790 - acc: 0.8554 - val_loss: 2.5526 - val_acc: 0.5486
#
# Epoch 00044: val_acc did not improve from 0.66374
# Epoch 45/100
#  - 35s - loss: 0.6796 - acc: 0.8554 - val_loss: 3.6441 - val_acc: 0.5773
#
# Epoch 00045: val_acc did not improve from 0.66374
# Epoch 46/100
#  - 35s - loss: 0.6700 - acc: 0.8566 - val_loss: 2.2103 - val_acc: 0.6144
#
# Epoch 00046: val_acc did not improve from 0.66374
# Epoch 47/100
#  - 35s - loss: 0.6760 - acc: 0.8536 - val_loss: 2.3524 - val_acc: 0.5178
#
# Epoch 00047: val_acc did not improve from 0.66374
# Epoch 48/100
#  - 34s - loss: 0.6701 - acc: 0.8596 - val_loss: 2.0440 - val_acc: 0.6128
#
# Epoch 00048: val_acc did not improve from 0.66374
# Epoch 49/100
#  - 34s - loss: 0.6702 - acc: 0.8566 - val_loss: 3.0493 - val_acc: 0.5550
#
# Epoch 00049: val_acc did not improve from 0.66374
# Epoch 50/100
#  - 34s - loss: 0.6645 - acc: 0.8590 - val_loss: 2.4628 - val_acc: 0.5820
#
# Epoch 00050: val_acc did not improve from 0.66374
# Epoch 51/100
#  - 35s - loss: 0.6664 - acc: 0.8611 - val_loss: 2.8432 - val_acc: 0.6255
#
# Epoch 00051: val_acc did not improve from 0.66374
# Epoch 52/100
#  - 35s - loss: 0.6611 - acc: 0.8609 - val_loss: 2.6492 - val_acc: 0.5962
#
# Epoch 00052: val_acc did not improve from 0.66374
# Epoch 53/100
#  - 34s - loss: 0.6622 - acc: 0.8611 - val_loss: 3.0055 - val_acc: 0.5847
#
# Epoch 00053: val_acc did not improve from 0.66374
# Epoch 54/100
#  - 34s - loss: 0.6590 - acc: 0.8611 - val_loss: 3.2269 - val_acc: 0.5459
#
# Epoch 00054: val_acc did not improve from 0.66374
# Epoch 55/100
#  - 34s - loss: 0.6603 - acc: 0.8602 - val_loss: 2.1236 - val_acc: 0.5793
#
# Epoch 00055: val_acc did not improve from 0.66374
# Epoch 56/100
#  - 35s - loss: 0.6561 - acc: 0.8616 - val_loss: 2.3268 - val_acc: 0.6363
#
# Epoch 00056: val_acc did not improve from 0.66374
# Epoch 57/100
#  - 34s - loss: 0.6551 - acc: 0.8642 - val_loss: 3.3875 - val_acc: 0.5833
#
# Epoch 00057: val_acc did not improve from 0.66374
# Epoch 58/100
#  - 34s - loss: 0.6526 - acc: 0.8667 - val_loss: 3.3973 - val_acc: 0.5401
#
# Epoch 00058: val_acc did not improve from 0.66374
# Epoch 59/100
#  - 35s - loss: 0.6512 - acc: 0.8651 - val_loss: 2.3995 - val_acc: 0.6507
#
# Epoch 00059: val_acc did not improve from 0.66374
# Epoch 60/100
#  - 35s - loss: 0.6480 - acc: 0.8643 - val_loss: 2.1698 - val_acc: 0.6189
#
# Epoch 00060: val_acc did not improve from 0.66374
# Epoch 61/100
#  - 35s - loss: 0.6501 - acc: 0.8641 - val_loss: 2.1407 - val_acc: 0.6579
#
# Epoch 00061: val_acc did not improve from 0.66374
# Epoch 62/100
#  - 35s - loss: 0.6466 - acc: 0.8637 - val_loss: 2.3237 - val_acc: 0.6394
#
# Epoch 00062: val_acc did not improve from 0.66374
# Epoch 63/100
#  - 35s - loss: 0.6484 - acc: 0.8650 - val_loss: 2.5951 - val_acc: 0.5065
#
# Epoch 00063: val_acc did not improve from 0.66374
# Epoch 64/100
#  - 35s - loss: 0.6427 - acc: 0.8665 - val_loss: 3.0721 - val_acc: 0.6126
#
# Epoch 00064: val_acc did not improve from 0.66374
# Epoch 65/100
#  - 35s - loss: 0.6453 - acc: 0.8647 - val_loss: 2.6137 - val_acc: 0.6059
#
# Epoch 00065: val_acc did not improve from 0.66374
# Epoch 66/100
#  - 35s - loss: 0.6411 - acc: 0.8677 - val_loss: 2.2842 - val_acc: 0.6372
#
# Epoch 00066: val_acc did not improve from 0.66374
# Epoch 67/100
#  - 34s - loss: 0.6432 - acc: 0.8700 - val_loss: 2.7717 - val_acc: 0.5279
#
# Epoch 00067: val_acc did not improve from 0.66374
# Epoch 68/100
#  - 35s - loss: 0.6366 - acc: 0.8729 - val_loss: 2.3722 - val_acc: 0.6072
#
# Epoch 00068: val_acc did not improve from 0.66374
# Epoch 69/100
#  - 35s - loss: 0.6409 - acc: 0.8719 - val_loss: 3.2906 - val_acc: 0.5631
#
# Epoch 00069: val_acc did not improve from 0.66374
# Epoch 70/100
#  - 35s - loss: 0.6364 - acc: 0.8720 - val_loss: 2.5549 - val_acc: 0.6455
#
# Epoch 00070: val_acc did not improve from 0.66374
# Epoch 71/100
#  - 35s - loss: 0.6352 - acc: 0.8736 - val_loss: 2.8045 - val_acc: 0.6196
#
# Epoch 00071: val_acc did not improve from 0.66374
# Epoch 72/100
#  - 34s - loss: 0.6365 - acc: 0.8719 - val_loss: 2.8848 - val_acc: 0.6196
#
# Epoch 00072: val_acc did not improve from 0.66374
# Epoch 73/100
#  - 35s - loss: 0.6328 - acc: 0.8704 - val_loss: 3.5877 - val_acc: 0.5489
#
# Epoch 00073: val_acc did not improve from 0.66374
# Epoch 74/100
#  - 35s - loss: 0.6355 - acc: 0.8712 - val_loss: 2.0739 - val_acc: 0.6579
#
# Epoch 00074: val_acc did not improve from 0.66374
# Epoch 75/100
#  - 35s - loss: 0.6310 - acc: 0.8738 - val_loss: 1.9305 - val_acc: 0.5752
#
# Epoch 00075: val_acc did not improve from 0.66374
# Epoch 76/100
#  - 35s - loss: 0.6297 - acc: 0.8713 - val_loss: 3.1727 - val_acc: 0.5912
#
# Epoch 00076: val_acc did not improve from 0.66374
# Epoch 77/100
#  - 35s - loss: 0.6289 - acc: 0.8732 - val_loss: 2.5090 - val_acc: 0.6354
#
# Epoch 00077: val_acc did not improve from 0.66374
# Epoch 78/100
#  - 35s - loss: 0.6291 - acc: 0.8729 - val_loss: 2.0972 - val_acc: 0.6536
#
# Epoch 00078: val_acc did not improve from 0.66374
# Epoch 79/100
#  - 35s - loss: 0.6283 - acc: 0.8773 - val_loss: 2.9504 - val_acc: 0.5752
#
# Epoch 00079: val_acc did not improve from 0.66374
# Epoch 80/100
#  - 35s - loss: 0.6313 - acc: 0.8751 - val_loss: 3.5811 - val_acc: 0.5599
#
# Epoch 00080: val_acc did not improve from 0.66374
# Epoch 81/100
#  - 35s - loss: 0.6235 - acc: 0.8764 - val_loss: 2.3949 - val_acc: 0.6331
#
# Epoch 00081: val_acc did not improve from 0.66374
# Epoch 82/100
#  - 34s - loss: 0.6260 - acc: 0.8745 - val_loss: 2.2293 - val_acc: 0.6122
#
# Epoch 00082: val_acc did not improve from 0.66374
# Epoch 83/100
#  - 35s - loss: 0.6231 - acc: 0.8805 - val_loss: 2.2332 - val_acc: 0.6236
#
# Epoch 00083: val_acc did not improve from 0.66374
# Epoch 84/100
#  - 35s - loss: 0.6231 - acc: 0.8774 - val_loss: 2.5237 - val_acc: 0.6381
#
# Epoch 00084: val_acc did not improve from 0.66374
# Epoch 85/100
#  - 35s - loss: 0.6277 - acc: 0.8749 - val_loss: 3.5151 - val_acc: 0.5315
#
# Epoch 00085: val_acc did not improve from 0.66374
# Epoch 86/100
#  - 35s - loss: 0.6290 - acc: 0.8753 - val_loss: 2.4369 - val_acc: 0.5901
#
# Epoch 00086: val_acc did not improve from 0.66374
# Epoch 87/100
#  - 35s - loss: 0.6162 - acc: 0.8787 - val_loss: 3.4130 - val_acc: 0.5836
#
# Epoch 00087: val_acc did not improve from 0.66374
# Epoch 88/100
#  - 34s - loss: 0.6195 - acc: 0.8752 - val_loss: 2.0768 - val_acc: 0.6633
#
# Epoch 00088: val_acc did not improve from 0.66374
# Epoch 89/100
#  - 34s - loss: 0.6185 - acc: 0.8798 - val_loss: 2.3869 - val_acc: 0.6473
#
# Epoch 00089: val_acc did not improve from 0.66374
# Epoch 90/100
#  - 34s - loss: 0.6186 - acc: 0.8790 - val_loss: 3.1344 - val_acc: 0.6187
#
# Epoch 00090: val_acc did not improve from 0.66374
# Epoch 91/100
#  - 34s - loss: 0.6178 - acc: 0.8803 - val_loss: 2.2319 - val_acc: 0.6432
#
# Epoch 00091: val_acc did not improve from 0.66374
# Epoch 92/100
#  - 34s - loss: 0.6136 - acc: 0.8811 - val_loss: 3.1248 - val_acc: 0.6047
#
# Epoch 00092: val_acc did not improve from 0.66374
# Epoch 93/100
#  - 34s - loss: 0.6212 - acc: 0.8809 - val_loss: 1.9344 - val_acc: 0.6545
#
# Epoch 00093: val_acc did not improve from 0.66374
# Epoch 94/100
#  - 34s - loss: 0.6128 - acc: 0.8812 - val_loss: 3.3847 - val_acc: 0.5723
#
# Epoch 00094: val_acc did not improve from 0.66374
# Epoch 95/100
#  - 35s - loss: 0.6193 - acc: 0.8785 - val_loss: 2.6672 - val_acc: 0.6032
#
# Epoch 00095: val_acc did not improve from 0.66374
# Epoch 96/100
#  - 35s - loss: 0.6151 - acc: 0.8801 - val_loss: 2.4545 - val_acc: 0.6450
#
# Epoch 00096: val_acc did not improve from 0.66374
# Epoch 97/100
#  - 35s - loss: 0.6154 - acc: 0.8824 - val_loss: 2.5512 - val_acc: 0.6221
#
# Epoch 00097: val_acc did not improve from 0.66374
# Epoch 98/100
#  - 35s - loss: 0.6118 - acc: 0.8832 - val_loss: 2.5060 - val_acc: 0.6349
#
# Epoch 00098: val_acc did not improve from 0.66374
# Epoch 99/100
#  - 35s - loss: 0.6144 - acc: 0.8814 - val_loss: 1.9842 - val_acc: 0.6505
#
# Epoch 00099: val_acc did not improve from 0.66374
# Epoch 100/100
#  - 35s - loss: 0.6106 - acc: 0.8854 - val_loss: 2.1092 - val_acc: 0.5414
#
# Epoch 00100: val_acc did not improve from 0.66374
# F1/Recall/Precision/Accuracy = 0.6471/0.6637/0.6930/0.6637
# Ensemble F1/Recall/Precision/Accuracy = 0.6674/0.6847/0.7173/0.6847
# Finished cycle #2.
#
#
# [Cycle #2]
# == Fold 2 ==
#  Dataset is not balanced so far, conf.data_balancing = by_generator
#  Using normal data generator, with class balancing
#  train_steps_per_epoch, valid_steps_per_epoch = 1951, 231
# Model: AlexNet based
# Epoch 1/100
#  - 35s - loss: 1.9433 - acc: 0.3281 - val_loss: 2.0034 - val_acc: 0.3715
#
# Epoch 00001: val_acc improved from -inf to 0.37146, saving model to model_weight_2.h5
# Epoch 2/100
#  - 34s - loss: 1.5382 - acc: 0.5015 - val_loss: 1.7302 - val_acc: 0.4281
#
# Epoch 00002: val_acc improved from 0.37146 to 0.42811, saving model to model_weight_2.h5
# Epoch 3/100
#  - 34s - loss: 1.3413 - acc: 0.5864 - val_loss: 1.7004 - val_acc: 0.4817
#
# Epoch 00003: val_acc improved from 0.42811 to 0.48173, saving model to model_weight_2.h5
# Epoch 4/100
#  - 34s - loss: 1.2122 - acc: 0.6406 - val_loss: 1.8218 - val_acc: 0.5049
#
# Epoch 00004: val_acc improved from 0.48173 to 0.50486, saving model to model_weight_2.h5
# Epoch 5/100
#  - 34s - loss: 1.1283 - acc: 0.6764 - val_loss: 1.7597 - val_acc: 0.5332
#
# Epoch 00005: val_acc improved from 0.50486 to 0.53319, saving model to model_weight_2.h5
# Epoch 6/100
#  - 34s - loss: 1.0631 - acc: 0.6997 - val_loss: 1.7984 - val_acc: 0.5351
#
# Epoch 00006: val_acc improved from 0.53319 to 0.53514, saving model to model_weight_2.h5
# Epoch 7/100
#  - 34s - loss: 1.0085 - acc: 0.7235 - val_loss: 2.9410 - val_acc: 0.4182
#
# Epoch 00007: val_acc did not improve from 0.53514
# Epoch 8/100
#  - 34s - loss: 0.9757 - acc: 0.7386 - val_loss: 1.6047 - val_acc: 0.5911
#
# Epoch 00008: val_acc improved from 0.53514 to 0.59114, saving model to model_weight_2.h5
# Epoch 9/100
#  - 34s - loss: 0.9449 - acc: 0.7522 - val_loss: 2.9922 - val_acc: 0.3278
#
# Epoch 00009: val_acc did not improve from 0.59114
# Epoch 10/100
#  - 34s - loss: 0.9162 - acc: 0.7588 - val_loss: 2.1972 - val_acc: 0.4863
#
# Epoch 00010: val_acc did not improve from 0.59114
# Epoch 11/100
#  - 34s - loss: 0.8928 - acc: 0.7654 - val_loss: 2.2722 - val_acc: 0.4837
#
# Epoch 00011: val_acc did not improve from 0.59114
# Epoch 12/100
#  - 34s - loss: 0.8856 - acc: 0.7772 - val_loss: 2.4378 - val_acc: 0.4618
#
# Epoch 00012: val_acc did not improve from 0.59114
# Epoch 13/100
#  - 34s - loss: 0.8615 - acc: 0.7842 - val_loss: 1.5751 - val_acc: 0.6214
#
# Epoch 00013: val_acc improved from 0.59114 to 0.62141, saving model to model_weight_2.h5
# Epoch 14/100
#  - 34s - loss: 0.8494 - acc: 0.7902 - val_loss: 1.8833 - val_acc: 0.5704
#
# Epoch 00014: val_acc did not improve from 0.62141
# Epoch 15/100
#  - 34s - loss: 0.8352 - acc: 0.7945 - val_loss: 2.2847 - val_acc: 0.4320
#
# Epoch 00015: val_acc did not improve from 0.62141
# Epoch 16/100
#  - 34s - loss: 0.8278 - acc: 0.7992 - val_loss: 1.6759 - val_acc: 0.5524
#
# Epoch 00016: val_acc did not improve from 0.62141
# Epoch 17/100
#  - 34s - loss: 0.8157 - acc: 0.8030 - val_loss: 1.8243 - val_acc: 0.5881
#
# Epoch 00017: val_acc did not improve from 0.62141
# Epoch 18/100
#  - 34s - loss: 0.7991 - acc: 0.8074 - val_loss: 1.9633 - val_acc: 0.6028
#
# Epoch 00018: val_acc did not improve from 0.62141
# Epoch 19/100
#  - 34s - loss: 0.7919 - acc: 0.8091 - val_loss: 2.5744 - val_acc: 0.5425
#
# Epoch 00019: val_acc did not improve from 0.62141
# Epoch 20/100
#  - 34s - loss: 0.7926 - acc: 0.8108 - val_loss: 1.7747 - val_acc: 0.6335
#
# Epoch 00020: val_acc improved from 0.62141 to 0.63351, saving model to model_weight_2.h5
# Epoch 21/100
#  - 34s - loss: 0.7768 - acc: 0.8159 - val_loss: 1.8692 - val_acc: 0.5650
#
# Epoch 00021: val_acc did not improve from 0.63351
# Epoch 22/100
#  - 34s - loss: 0.7716 - acc: 0.8176 - val_loss: 2.3950 - val_acc: 0.5379
#
# Epoch 00022: val_acc did not improve from 0.63351
# Epoch 23/100
#  - 34s - loss: 0.7721 - acc: 0.8172 - val_loss: 1.7318 - val_acc: 0.6082
#
# Epoch 00023: val_acc did not improve from 0.63351
# Epoch 24/100
#  - 34s - loss: 0.7598 - acc: 0.8236 - val_loss: 2.2810 - val_acc: 0.5518
#
# Epoch 00024: val_acc did not improve from 0.63351
# Epoch 25/100
#  - 34s - loss: 0.7571 - acc: 0.8233 - val_loss: 1.5917 - val_acc: 0.6536
#
# Epoch 00025: val_acc improved from 0.63351 to 0.65362, saving model to model_weight_2.h5
# Epoch 26/100
#  - 34s - loss: 0.7455 - acc: 0.8269 - val_loss: 2.3405 - val_acc: 0.5680
#
# Epoch 00026: val_acc did not improve from 0.65362
# Epoch 27/100
#  - 34s - loss: 0.7424 - acc: 0.8269 - val_loss: 2.8233 - val_acc: 0.5390
#
# Epoch 00027: val_acc did not improve from 0.65362
# Epoch 28/100
#  - 34s - loss: 0.7349 - acc: 0.8325 - val_loss: 4.1315 - val_acc: 0.4675
#
# Epoch 00028: val_acc did not improve from 0.65362
# Epoch 29/100
#  - 34s - loss: 0.7356 - acc: 0.8324 - val_loss: 2.2734 - val_acc: 0.6091
#
# Epoch 00029: val_acc did not improve from 0.65362
# Epoch 30/100
#  - 34s - loss: 0.7267 - acc: 0.8341 - val_loss: 2.5018 - val_acc: 0.5736
#
# Epoch 00030: val_acc did not improve from 0.65362
# Epoch 31/100
#  - 34s - loss: 0.7217 - acc: 0.8352 - val_loss: 2.3672 - val_acc: 0.5939
#
# Epoch 00031: val_acc did not improve from 0.65362
# Epoch 32/100
#  - 34s - loss: 0.7179 - acc: 0.8352 - val_loss: 2.2017 - val_acc: 0.6063
#
# Epoch 00032: val_acc did not improve from 0.65362
# Epoch 33/100
#  - 34s - loss: 0.7175 - acc: 0.8393 - val_loss: 1.9325 - val_acc: 0.6158
#
# Epoch 00033: val_acc did not improve from 0.65362
# Epoch 34/100
#  - 34s - loss: 0.7091 - acc: 0.8415 - val_loss: 2.2044 - val_acc: 0.5946
#
# Epoch 00034: val_acc did not improve from 0.65362
# Epoch 35/100
#  - 34s - loss: 0.7116 - acc: 0.8414 - val_loss: 1.9205 - val_acc: 0.6244
#
# Epoch 00035: val_acc did not improve from 0.65362
# Epoch 36/100
#  - 34s - loss: 0.7026 - acc: 0.8421 - val_loss: 2.4295 - val_acc: 0.6162
#
# Epoch 00036: val_acc did not improve from 0.65362
# Epoch 37/100
#  - 34s - loss: 0.7032 - acc: 0.8433 - val_loss: 2.1414 - val_acc: 0.6022
#
# Epoch 00037: val_acc did not improve from 0.65362
# Epoch 38/100
#  - 34s - loss: 0.6977 - acc: 0.8447 - val_loss: 4.2197 - val_acc: 0.4999
#
# Epoch 00038: val_acc did not improve from 0.65362
# Epoch 39/100
#  - 34s - loss: 0.6947 - acc: 0.8420 - val_loss: 2.8572 - val_acc: 0.5795
#
# Epoch 00039: val_acc did not improve from 0.65362
# Epoch 40/100
#  - 34s - loss: 0.6938 - acc: 0.8451 - val_loss: 2.2931 - val_acc: 0.5721
#
# Epoch 00040: val_acc did not improve from 0.65362
# Epoch 41/100
#  - 34s - loss: 0.6914 - acc: 0.8483 - val_loss: 2.2698 - val_acc: 0.6192
#
# Epoch 00041: val_acc did not improve from 0.65362
# Epoch 42/100
#  - 34s - loss: 0.6848 - acc: 0.8494 - val_loss: 2.3014 - val_acc: 0.5890
#
# Epoch 00042: val_acc did not improve from 0.65362
# Epoch 43/100
#  - 34s - loss: 0.6893 - acc: 0.8453 - val_loss: 2.2841 - val_acc: 0.6128
#
# Epoch 00043: val_acc did not improve from 0.65362
# Epoch 44/100
#  - 34s - loss: 0.6837 - acc: 0.8506 - val_loss: 2.3990 - val_acc: 0.5423
#
# Epoch 00044: val_acc did not improve from 0.65362
# Epoch 45/100
#  - 34s - loss: 0.6833 - acc: 0.8528 - val_loss: 3.0096 - val_acc: 0.5455
#
# Epoch 00045: val_acc did not improve from 0.65362
# Epoch 46/100
#  - 34s - loss: 0.6732 - acc: 0.8543 - val_loss: 2.0401 - val_acc: 0.5606
#
# Epoch 00046: val_acc did not improve from 0.65362
# Epoch 47/100
#  - 34s - loss: 0.6752 - acc: 0.8546 - val_loss: 1.9175 - val_acc: 0.6128
#
# Epoch 00047: val_acc did not improve from 0.65362
# Epoch 48/100
#  - 34s - loss: 0.6734 - acc: 0.8532 - val_loss: 2.0874 - val_acc: 0.6339
#
# Epoch 00048: val_acc did not improve from 0.65362
# Epoch 49/100
#  - 34s - loss: 0.6733 - acc: 0.8555 - val_loss: 2.1301 - val_acc: 0.6221
#
# Epoch 00049: val_acc did not improve from 0.65362
# Epoch 50/100
#  - 34s - loss: 0.6701 - acc: 0.8589 - val_loss: 2.3347 - val_acc: 0.5732
#
# Epoch 00050: val_acc did not improve from 0.65362
# Epoch 51/100
#  - 34s - loss: 0.6679 - acc: 0.8581 - val_loss: 2.3697 - val_acc: 0.5846
#
# Epoch 00051: val_acc did not improve from 0.65362
# Epoch 52/100
#  - 34s - loss: 0.6657 - acc: 0.8592 - val_loss: 2.1426 - val_acc: 0.6272
#
# Epoch 00052: val_acc did not improve from 0.65362
# Epoch 53/100
#  - 34s - loss: 0.6631 - acc: 0.8607 - val_loss: 2.3177 - val_acc: 0.6428
#
# Epoch 00053: val_acc did not improve from 0.65362
# Epoch 54/100
#  - 34s - loss: 0.6606 - acc: 0.8612 - val_loss: 2.4584 - val_acc: 0.5613
#
# Epoch 00054: val_acc did not improve from 0.65362
# Epoch 55/100
#  - 34s - loss: 0.6556 - acc: 0.8576 - val_loss: 3.4288 - val_acc: 0.5390
#
# Epoch 00055: val_acc did not improve from 0.65362
# Epoch 56/100
#  - 34s - loss: 0.6614 - acc: 0.8614 - val_loss: 2.5632 - val_acc: 0.6043
#
# Epoch 00056: val_acc did not improve from 0.65362
# Epoch 57/100
#  - 34s - loss: 0.6592 - acc: 0.8624 - val_loss: 2.3123 - val_acc: 0.5777
#
# Epoch 00057: val_acc did not improve from 0.65362
# Epoch 58/100
#  - 34s - loss: 0.6535 - acc: 0.8621 - val_loss: 2.7039 - val_acc: 0.5786
#
# Epoch 00058: val_acc did not improve from 0.65362
# Epoch 59/100
#  - 34s - loss: 0.6551 - acc: 0.8631 - val_loss: 2.6756 - val_acc: 0.5684
#
# Epoch 00059: val_acc did not improve from 0.65362
# Epoch 60/100
#  - 34s - loss: 0.6507 - acc: 0.8624 - val_loss: 3.2797 - val_acc: 0.4845
#
# Epoch 00060: val_acc did not improve from 0.65362
# Epoch 61/100
#  - 34s - loss: 0.6502 - acc: 0.8635 - val_loss: 2.2351 - val_acc: 0.6352
#
# Epoch 00061: val_acc did not improve from 0.65362
# Epoch 62/100
#  - 34s - loss: 0.6499 - acc: 0.8666 - val_loss: 2.3237 - val_acc: 0.6404
#
# Epoch 00062: val_acc did not improve from 0.65362
# Epoch 63/100
#  - 34s - loss: 0.6503 - acc: 0.8630 - val_loss: 2.2780 - val_acc: 0.5790
#
# Epoch 00063: val_acc did not improve from 0.65362
# Epoch 64/100
#  - 34s - loss: 0.6472 - acc: 0.8633 - val_loss: 2.2322 - val_acc: 0.6106
#
# Epoch 00064: val_acc did not improve from 0.65362
# Epoch 65/100
#  - 34s - loss: 0.6492 - acc: 0.8615 - val_loss: 2.1113 - val_acc: 0.6160
#
# Epoch 00065: val_acc did not improve from 0.65362
# Epoch 66/100
#  - 34s - loss: 0.6407 - acc: 0.8668 - val_loss: 2.9732 - val_acc: 0.5578
#
# Epoch 00066: val_acc did not improve from 0.65362
# Epoch 67/100
#  - 34s - loss: 0.6425 - acc: 0.8677 - val_loss: 2.3546 - val_acc: 0.5952
#
# Epoch 00067: val_acc did not improve from 0.65362
# Epoch 68/100
#  - 34s - loss: 0.6422 - acc: 0.8654 - val_loss: 2.7825 - val_acc: 0.5624
#
# Epoch 00068: val_acc did not improve from 0.65362
# Epoch 69/100
#  - 34s - loss: 0.6430 - acc: 0.8666 - val_loss: 2.4565 - val_acc: 0.6441
#
# Epoch 00069: val_acc did not improve from 0.65362
# Epoch 70/100
#  - 34s - loss: 0.6433 - acc: 0.8681 - val_loss: 2.2351 - val_acc: 0.5978
#
# Epoch 00070: val_acc did not improve from 0.65362
# Epoch 71/100
#  - 34s - loss: 0.6348 - acc: 0.8690 - val_loss: 1.9819 - val_acc: 0.6104
#
# Epoch 00071: val_acc did not improve from 0.65362
# Epoch 72/100
#  - 34s - loss: 0.6358 - acc: 0.8681 - val_loss: 2.1275 - val_acc: 0.6474
#
# Epoch 00075: val_acc did not improve from 0.65751
# Epoch 76/100
#  - 34s - loss: 0.6301 - acc: 0.8723 - val_loss: 2.5695 - val_acc: 0.5808
#
# Epoch 00076: val_acc did not improve from 0.65751
# Epoch 77/100
#  - 34s - loss: 0.6306 - acc: 0.8723 - val_loss: 2.6025 - val_acc: 0.6160
#
# Epoch 00077: val_acc did not improve from 0.65751
# Epoch 78/100
#  - 34s - loss: 0.6336 - acc: 0.8696 - val_loss: 2.5035 - val_acc: 0.6166
#
# Epoch 00078: val_acc did not improve from 0.65751
# Epoch 79/100
#  - 34s - loss: 0.6318 - acc: 0.8707 - val_loss: 2.2888 - val_acc: 0.6478
# Epoch 00079: val_acc did not improve from 0.65751
# Epoch 80/100
#  - 34s - loss: 0.6287 - acc: 0.8720 - val_loss: 3.2640 - val_acc: 0.5691
#
# Epoch 00080: val_acc did not improve from 0.65751
# Epoch 81/100
#  - 34s - loss: 0.6296 - acc: 0.8730 - val_loss: 2.1826 - val_acc: 0.6597
#
# Epoch 00081: val_acc improved from 0.65751 to 0.65968, saving model to model_weight_2.h5
# Epoch 82/100
#  - 34s - loss: 0.6288 - acc: 0.8739 - val_loss: 4.6831 - val_acc: 0.4210
#
# Epoch 00082: val_acc did not improve from 0.65968
# Epoch 83/100
#  - 34s - loss: 0.6242 - acc: 0.8758 - val_loss: 2.2911 - val_acc: 0.6610
#
# Epoch 00083: val_acc improved from 0.65968 to 0.66097, saving model to model_weight_2.h5
# Epoch 84/100
#  - 34s - loss: 0.6224 - acc: 0.8759 - val_loss: 2.2695 - val_acc: 0.6216
#
# Epoch 00084: val_acc did not improve from 0.66097
# Epoch 85/100
#  - 34s - loss: 0.6258 - acc: 0.8771 - val_loss: 2.5702 - val_acc: 0.6119
#
# Epoch 00085: val_acc did not improve from 0.66097
# Epoch 86/100
#  - 34s - loss: 0.6256 - acc: 0.8748 - val_loss: 2.1457 - val_acc: 0.6616
#
# Epoch 00086: val_acc improved from 0.66097 to 0.66162, saving model to model_weight_2.h5
# Epoch 87/100
#  - 34s - loss: 0.6291 - acc: 0.8717 - val_loss: 2.1175 - val_acc: 0.6006
#
# Epoch 00087: val_acc did not improve from 0.66162
# Epoch 88/100
#  - 34s - loss: 0.6205 - acc: 0.8761 - val_loss: 2.5430 - val_acc: 0.6147
#
# Epoch 00088: val_acc did not improve from 0.66162
# Epoch 89/100
#  - 34s - loss: 0.6220 - acc: 0.8749 - val_loss: 2.6034 - val_acc: 0.6067
#
# Epoch 00089: val_acc did not improve from 0.66162
# Epoch 90/100
#  - 34s - loss: 0.6218 - acc: 0.8767 - val_loss: 2.5011 - val_acc: 0.6309
#
# Epoch 00090: val_acc did not improve from 0.66162
# Epoch 91/100
#  - 34s - loss: 0.6218 - acc: 0.8767 - val_loss: 4.3596 - val_acc: 0.5399
#
# Epoch 00091: val_acc did not improve from 0.66162
# Epoch 92/100
#  - 34s - loss: 0.6177 - acc: 0.8792 - val_loss: 3.4374 - val_acc: 0.5431
#
# Epoch 00092: val_acc did not improve from 0.66162
# Epoch 93/100
#  - 34s - loss: 0.6157 - acc: 0.8774 - val_loss: 2.3639 - val_acc: 0.6234
#
# Epoch 00093: val_acc did not improve from 0.66162
# Epoch 94/100
#  - 34s - loss: 0.6175 - acc: 0.8749 - val_loss: 4.4485 - val_acc: 0.4876
#
# Epoch 00094: val_acc did not improve from 0.66162
# Epoch 95/100
#  - 34s - loss: 0.6178 - acc: 0.8747 - val_loss: 2.3920 - val_acc: 0.5373
#
# Epoch 00095: val_acc did not improve from 0.66162
# Epoch 96/100
#  - 34s - loss: 0.6176 - acc: 0.8794 - val_loss: 2.8942 - val_acc: 0.5991
#
# Epoch 00096: val_acc did not improve from 0.66162
# Epoch 97/100
#  - 34s - loss: 0.6152 - acc: 0.8775 - val_loss: 3.2958 - val_acc: 0.5650
#
# Epoch 00097: val_acc did not improve from 0.66162
# Epoch 98/100
#  - 34s - loss: 0.6205 - acc: 0.8787 - val_loss: 2.4463 - val_acc: 0.6156
#
# Epoch 00098: val_acc did not improve from 0.66162
# Epoch 99/100
#  - 34s - loss: 0.6125 - acc: 0.8800 - val_loss: 2.1687 - val_acc: 0.6394
#
# Epoch 00099: val_acc did not improve from 0.66162
# Epoch 100/100
#  - 34s - loss: 0.6154 - acc: 0.8799 - val_loss: 2.0781 - val_acc: 0.5916
#
# Epoch 00100: val_acc did not improve from 0.66162
# F1/Recall/Precision/Accuracy = 0.6450/0.6616/0.6433/0.6616
# Ensemble F1/Recall/Precision/Accuracy = 0.6553/0.6757/0.6512/0.6757
# Finished cycle #3.
#
#
# [Cycle #3]
# == Fold 3 ==
#  Dataset is not balanced so far, conf.data_balancing = by_generator
#  Using normal data generator, with class balancing
#  train_steps_per_epoch, valid_steps_per_epoch = 1935, 247
# Model: AlexNet based
# Epoch 1/100
#  - 35s - loss: 1.9312 - acc: 0.3378 - val_loss: 3.2537 - val_acc: 0.2485
#
# Epoch 00001: val_acc improved from -inf to 0.24848, saving model to model_weight_3.h5
# Epoch 2/100
#  - 34s - loss: 1.5014 - acc: 0.5167 - val_loss: 1.5336 - val_acc: 0.4851
#
# Epoch 00002: val_acc improved from 0.24848 to 0.48505, saving model to model_weight_3.h5
# Epoch 3/100
#  - 34s - loss: 1.3071 - acc: 0.5984 - val_loss: 1.5009 - val_acc: 0.4972
#
# Epoch 00003: val_acc improved from 0.48505 to 0.49717, saving model to model_weight_3.h5
# Epoch 4/100
#  - 34s - loss: 1.1895 - acc: 0.6533 - val_loss: 1.5783 - val_acc: 0.5481
#
# Epoch 00004: val_acc improved from 0.49717 to 0.54808, saving model to model_weight_3.h5
# Epoch 5/100
#  - 34s - loss: 1.1048 - acc: 0.6825 - val_loss: 2.7025 - val_acc: 0.4295
#
# Epoch 00005: val_acc did not improve from 0.54808
# Epoch 6/100
#  - 34s - loss: 1.0475 - acc: 0.7111 - val_loss: 1.5263 - val_acc: 0.5570
#
# Epoch 00006: val_acc improved from 0.54808 to 0.55697, saving model to model_weight_3.h5
# Epoch 7/100
#  - 34s - loss: 1.0081 - acc: 0.7255 - val_loss: 1.7996 - val_acc: 0.5271
#
# Epoch 00007: val_acc did not improve from 0.55697
# Epoch 8/100
#  - 34s - loss: 0.9623 - acc: 0.7459 - val_loss: 1.7350 - val_acc: 0.5705
#
# Epoch 00008: val_acc improved from 0.55697 to 0.57051, saving model to model_weight_3.h5
# Epoch 9/100
#  - 34s - loss: 0.9365 - acc: 0.7567 - val_loss: 1.6798 - val_acc: 0.5952
#
# Epoch 00009: val_acc improved from 0.57051 to 0.59515, saving model to model_weight_3.h5
# Epoch 10/100
#  - 34s - loss: 0.9147 - acc: 0.7582 - val_loss: 2.0337 - val_acc: 0.5717
#
# Epoch 00010: val_acc did not improve from 0.59515
# Epoch 11/100
#  - 34s - loss: 0.8859 - acc: 0.7746 - val_loss: 1.7519 - val_acc: 0.5677
#
# Epoch 00011: val_acc did not improve from 0.59515
# Epoch 12/100
#  - 34s - loss: 0.8706 - acc: 0.7814 - val_loss: 2.4160 - val_acc: 0.4820
#
# Epoch 00012: val_acc did not improve from 0.59515
# Epoch 13/100
#  - 34s - loss: 0.8537 - acc: 0.7886 - val_loss: 2.7419 - val_acc: 0.4549
#
# Epoch 00013: val_acc did not improve from 0.59515
# Epoch 14/100
#  - 34s - loss: 0.8396 - acc: 0.7923 - val_loss: 1.9235 - val_acc: 0.6038
#
# Epoch 00014: val_acc improved from 0.59515 to 0.60384, saving model to model_weight_3.h5
# Epoch 15/100
#  - 34s - loss: 0.8283 - acc: 0.7953 - val_loss: 1.4092 - val_acc: 0.6642
#
# Epoch 00015: val_acc improved from 0.60384 to 0.66424, saving model to model_weight_3.h5
# Epoch 16/100
#  - 34s - loss: 0.8206 - acc: 0.7955 - val_loss: 2.0515 - val_acc: 0.5578
#
# Epoch 00016: val_acc did not improve from 0.66424
# Epoch 17/100
#  - 34s - loss: 0.8057 - acc: 0.8008 - val_loss: 1.3796 - val_acc: 0.6279
#
# Epoch 00017: val_acc did not improve from 0.66424
# Epoch 18/100
#  - 34s - loss: 0.7979 - acc: 0.8072 - val_loss: 1.7550 - val_acc: 0.5899
#
# Epoch 00018: val_acc did not improve from 0.66424
# Epoch 19/100
#  - 34s - loss: 0.7891 - acc: 0.8104 - val_loss: 1.5466 - val_acc: 0.6378
#
# Epoch 00019: val_acc did not improve from 0.66424
# Epoch 20/100
#  - 34s - loss: 0.7858 - acc: 0.8115 - val_loss: 1.4872 - val_acc: 0.6079
#
# Epoch 00020: val_acc did not improve from 0.66424
# Epoch 21/100
#  - 34s - loss: 0.7758 - acc: 0.8152 - val_loss: 2.1278 - val_acc: 0.5210
#
# Epoch 00021: val_acc did not improve from 0.66424
# Epoch 22/100
#  - 34s - loss: 0.7643 - acc: 0.8171 - val_loss: 1.9987 - val_acc: 0.6362
#
# Epoch 00022: val_acc did not improve from 0.66424
# Epoch 23/100
#  - 34s - loss: 0.7596 - acc: 0.8195 - val_loss: 2.0617 - val_acc: 0.5996
#
# ...
# Epoch 93/100
#  - 37s - loss: 0.6215 - acc: 0.8809 - val_loss: 1.8674 - val_acc: 0.6917
#
# Epoch 00093: val_acc did not improve from 0.72402
# Epoch 94/100
#  - 36s - loss: 0.6160 - acc: 0.8812 - val_loss: 2.0948 - val_acc: 0.6419
#
# Epoch 00094: val_acc did not improve from 0.72402
# Epoch 95/100
#  - 36s - loss: 0.6143 - acc: 0.8838 - val_loss: 1.7645 - val_acc: 0.7069
#
# Epoch 00095: val_acc did not improve from 0.72402
# Epoch 96/100
#  - 37s - loss: 0.6159 - acc: 0.8802 - val_loss: 1.6474 - val_acc: 0.7169
#
# Epoch 00096: val_acc did not improve from 0.72402
# Epoch 97/100
#  - 36s - loss: 0.6146 - acc: 0.8807 - val_loss: 1.9564 - val_acc: 0.6676
#
# Epoch 00097: val_acc did not improve from 0.72402
# Epoch 98/100
#  - 36s - loss: 0.6149 - acc: 0.8819 - val_loss: 1.5906 - val_acc: 0.6657
#
# Epoch 00098: val_acc did not improve from 0.72402
# Epoch 99/100
#  - 36s - loss: 0.6139 - acc: 0.8828 - val_loss: 1.6521 - val_acc: 0.7135
#
# Epoch 00099: val_acc did not improve from 0.72402
# Epoch 100/100
#  - 37s - loss: 0.6126 - acc: 0.8833 - val_loss: 1.5673 - val_acc: 0.7125
#
# Epoch 00100: val_acc did not improve from 0.72402
# F1/Recall/Precision/Accuracy = 0.7043/0.7240/0.7247/0.7240
# Ensemble F1/Recall/Precision/Accuracy = 0.7296/0.7488/0.7492/0.7488
# Finished cycle #9.
#
#
# [Cycle #9]
# == Fold 9 ==
#  Dataset is not balanced so far, conf.data_balancing = by_generator
#  Using normal data generator, with class balancing
#  train_steps_per_epoch, valid_steps_per_epoch = 1973, 209
# Model: AlexNet based
# Epoch 1/100
#  - 37s - loss: 1.9563 - acc: 0.3300 - val_loss: 2.1421 - val_acc: 0.2824
#
# Epoch 00001: val_acc improved from -inf to 0.28244, saving model to model_weight_9.h5
# Epoch 2/100
#  - 37s - loss: 1.5251 - acc: 0.5113 - val_loss: 1.4097 - val_acc: 0.6031
#
# Epoch 00002: val_acc improved from 0.28244 to 0.60311, saving model to model_weight_9.h5
# Epoch 3/100
#  - 36s - loss: 1.3413 - acc: 0.5845 - val_loss: 1.4576 - val_acc: 0.6411
#
# Epoch 00003: val_acc improved from 0.60311 to 0.64110, saving model to model_weight_9.h5
# Epoch 4/100
#  - 36s - loss: 1.2047 - acc: 0.6411 - val_loss: 1.7039 - val_acc: 0.5658
#
# Epoch 00004: val_acc did not improve from 0.64110
# Epoch 5/100
#  - 37s - loss: 1.1250 - acc: 0.6768 - val_loss: 1.4062 - val_acc: 0.6554
#
# Epoch 00005: val_acc improved from 0.64110 to 0.65544, saving model to model_weight_9.h5
# Epoch 6/100
#  - 37s - loss: 1.0619 - acc: 0.7011 - val_loss: 2.0117 - val_acc: 0.5145
#
# Epoch 00006: val_acc did not improve from 0.65544
# Epoch 7/100
#  - 37s - loss: 1.0027 - acc: 0.7276 - val_loss: 1.2322 - val_acc: 0.7123
#
# Epoch 00007: val_acc improved from 0.65544 to 0.71231, saving model to model_weight_9.h5
# Epoch 8/100
#  - 36s - loss: 0.9735 - acc: 0.7398 - val_loss: 2.9313 - val_acc: 0.3959
#
# Epoch 00008: val_acc did not improve from 0.71231
# Epoch 9/100
#  - 36s - loss: 0.9450 - acc: 0.7521 - val_loss: 1.6634 - val_acc: 0.5723
#
# Epoch 00009: val_acc did not improve from 0.71231
# Epoch 10/100
#  - 36s - loss: 0.9168 - acc: 0.7631 - val_loss: 1.7866 - val_acc: 0.6136
#
# Epoch 00010: val_acc did not improve from 0.71231
# Epoch 11/100
#  - 37s - loss: 0.8975 - acc: 0.7738 - val_loss: 1.8853 - val_acc: 0.4953
#
# Epoch 00011: val_acc did not improve from 0.71231
# Epoch 12/100
#  - 36s - loss: 0.8811 - acc: 0.7794 - val_loss: 1.4700 - val_acc: 0.6526
#
# Epoch 00012: val_acc did not improve from 0.71231
# Epoch 13/100
#  - 37s - loss: 0.8630 - acc: 0.7862 - val_loss: 1.6370 - val_acc: 0.6191
#
# Epoch 00013: val_acc did not improve from 0.71231
# Epoch 14/100
#  - 37s - loss: 0.8577 - acc: 0.7847 - val_loss: 2.3789 - val_acc: 0.4657
#
# Epoch 00014: val_acc did not improve from 0.71231
# Epoch 15/100
#  - 36s - loss: 0.8363 - acc: 0.7945 - val_loss: 2.8654 - val_acc: 0.4963
#
# Epoch 00015: val_acc did not improve from 0.71231
# Epoch 16/100
#  - 37s - loss: 0.8263 - acc: 0.8019 - val_loss: 1.5988 - val_acc: 0.6490
#
# Epoch 00016: val_acc did not improve from 0.71231
# Epoch 17/100
#  - 37s - loss: 0.8165 - acc: 0.8034 - val_loss: 1.6099 - val_acc: 0.6270
#
# Epoch 00017: val_acc did not improve from 0.71231
# Epoch 18/100
#  - 36s - loss: 0.8052 - acc: 0.8070 - val_loss: 1.8794 - val_acc: 0.6076
#
# Epoch 00018: val_acc did not improve from 0.71231
# Epoch 19/100
#  - 36s - loss: 0.8027 - acc: 0.8089 - val_loss: 2.4470 - val_acc: 0.5740
#
# Epoch 00019: val_acc did not improve from 0.71231
# Epoch 20/100
#  - 37s - loss: 0.7882 - acc: 0.8148 - val_loss: 1.5539 - val_acc: 0.6863
#
# Epoch 00020: val_acc did not improve from 0.71231
# Epoch 21/100
#  - 37s - loss: 0.7775 - acc: 0.8157 - val_loss: 1.6101 - val_acc: 0.6736
#
# Epoch 00021: val_acc did not improve from 0.71231
# Epoch 22/100
#  - 37s - loss: 0.7715 - acc: 0.8191 - val_loss: 1.4286 - val_acc: 0.6982
#
# Epoch 00022: val_acc did not improve from 0.71231
# Epoch 23/100
#  - 36s - loss: 0.7650 - acc: 0.8196 - val_loss: 1.5849 - val_acc: 0.6695
#
# Epoch 00023: val_acc did not improve from 0.71231
# Epoch 24/100
#  - 37s - loss: 0.7561 - acc: 0.8212 - val_loss: 1.7443 - val_acc: 0.6576
#
# Epoch 00024: val_acc did not improve from 0.71231
# Epoch 25/100
#  - 37s - loss: 0.7471 - acc: 0.8270 - val_loss: 1.3966 - val_acc: 0.6968
#
# Epoch 00025: val_acc did not improve from 0.71231
# Epoch 26/100
#  - 36s - loss: 0.7483 - acc: 0.8253 - val_loss: 2.1815 - val_acc: 0.6401
#
# Epoch 00026: val_acc did not improve from 0.71231
# Epoch 27/100
#  - 36s - loss: 0.7425 - acc: 0.8283 - val_loss: 1.7464 - val_acc: 0.5606
#
# Epoch 00027: val_acc did not improve from 0.71231
# Epoch 28/100
#  - 37s - loss: 0.7380 - acc: 0.8298 - val_loss: 1.7421 - val_acc: 0.6554
#
# Epoch 00028: val_acc did not improve from 0.71231
# Epoch 29/100
#  - 37s - loss: 0.7337 - acc: 0.8341 - val_loss: 1.5790 - val_acc: 0.6870
#
# Epoch 00029: val_acc did not improve from 0.71231
# Epoch 30/100
#  - 37s - loss: 0.7282 - acc: 0.8347 - val_loss: 2.2026 - val_acc: 0.6050
#
# Epoch 00030: val_acc did not improve from 0.71231
# Epoch 31/100
#  - 37s - loss: 0.7251 - acc: 0.8349 - val_loss: 1.8798 - val_acc: 0.5928
#
# Epoch 00031: val_acc did not improve from 0.71231
# Epoch 32/100
#  - 37s - loss: 0.7224 - acc: 0.8323 - val_loss: 1.8038 - val_acc: 0.6155
#
# Epoch 00032: val_acc did not improve from 0.71231
# Epoch 33/100
#  - 37s - loss: 0.7161 - acc: 0.8399 - val_loss: 1.8893 - val_acc: 0.6294
#
# Epoch 00033: val_acc did not improve from 0.71231
# Epoch 34/100
#  - 37s - loss: 0.7136 - acc: 0.8391 - val_loss: 1.4883 - val_acc: 0.7001
#
# Epoch 00034: val_acc did not improve from 0.71231
# Epoch 35/100
#  - 37s - loss: 0.7098 - acc: 0.8404 - val_loss: 2.0080 - val_acc: 0.6332
#
# Epoch 00035: val_acc did not improve from 0.71231
# Epoch 36/100
#  - 37s - loss: 0.7050 - acc: 0.8441 - val_loss: 1.7747 - val_acc: 0.6722
#
# Epoch 00036: val_acc did not improve from 0.71231
# Epoch 37/100
#  - 37s - loss: 0.6992 - acc: 0.8429 - val_loss: 1.9302 - val_acc: 0.6487
#
# Epoch 00037: val_acc did not improve from 0.71231
# Epoch 38/100
#  - 37s - loss: 0.7030 - acc: 0.8437 - val_loss: 1.8056 - val_acc: 0.6507
#
# Epoch 00038: val_acc did not improve from 0.71231
# Epoch 39/100
#  - 37s - loss: 0.7002 - acc: 0.8449 - val_loss: 1.8010 - val_acc: 0.6714
#
# Epoch 00039: val_acc did not improve from 0.71231
# Epoch 40/100
#  - 37s - loss: 0.6932 - acc: 0.8495 - val_loss: 1.7968 - val_acc: 0.6533
#
# Epoch 00040: val_acc did not improve from 0.71231
# Epoch 41/100
#  - 37s - loss: 0.6931 - acc: 0.8495 - val_loss: 1.6757 - val_acc: 0.6495
#
# Epoch 00041: val_acc did not improve from 0.71231
# Epoch 42/100
#  - 37s - loss: 0.6840 - acc: 0.8506 - val_loss: 1.6197 - val_acc: 0.6657
#
# Epoch 00042: val_acc did not improve from 0.71231
# Epoch 43/100
#  - 37s - loss: 0.6894 - acc: 0.8496 - val_loss: 1.8005 - val_acc: 0.6521
#
# Epoch 00043: val_acc did not improve from 0.71231
# Epoch 44/100
#  - 37s - loss: 0.6778 - acc: 0.8514 - val_loss: 2.0927 - val_acc: 0.6174
#
# Epoch 00044: val_acc did not improve from 0.71231
# Epoch 45/100
#  - 37s - loss: 0.6818 - acc: 0.8540 - val_loss: 1.7254 - val_acc: 0.6774
#
# Epoch 00045: val_acc did not improve from 0.71231
# Epoch 46/100
#  - 37s - loss: 0.6772 - acc: 0.8519 - val_loss: 1.7028 - val_acc: 0.6726
#
# Epoch 00046: val_acc did not improve from 0.71231
# Epoch 47/100
#  - 37s - loss: 0.6721 - acc: 0.8550 - val_loss: 2.0478 - val_acc: 0.6464
#
# Epoch 00047: val_acc did not improve from 0.71231
# Epoch 48/100
#  - 37s - loss: 0.6696 - acc: 0.8577 - val_loss: 1.7501 - val_acc: 0.6640
#
# Epoch 00048: val_acc did not improve from 0.71231
# Epoch 49/100
#  - 37s - loss: 0.6720 - acc: 0.8552 - val_loss: 1.6533 - val_acc: 0.6714
#
# Epoch 00049: val_acc did not improve from 0.71231
# Epoch 50/100
#  - 37s - loss: 0.6681 - acc: 0.8571 - val_loss: 1.9931 - val_acc: 0.6583
#
# Epoch 00050: val_acc did not improve from 0.71231
# Epoch 51/100
#  - 37s - loss: 0.6685 - acc: 0.8583 - val_loss: 1.7132 - val_acc: 0.6884
#
# Epoch 00051: val_acc did not improve from 0.71231
# Epoch 52/100
#  - 37s - loss: 0.6617 - acc: 0.8577 - val_loss: 1.7957 - val_acc: 0.6609
#
# Epoch 00052: val_acc did not improve from 0.71231
# Epoch 53/100
#  - 37s - loss: 0.6645 - acc: 0.8586 - val_loss: 2.0294 - val_acc: 0.6315
#
# Epoch 00053: val_acc did not improve from 0.71231
# Epoch 54/100
#  - 37s - loss: 0.6652 - acc: 0.8607 - val_loss: 2.1758 - val_acc: 0.6339
#
# Epoch 00054: val_acc did not improve from 0.71231
# Epoch 55/100
#  - 37s - loss: 0.6548 - acc: 0.8605 - val_loss: 1.6176 - val_acc: 0.6901
#
# Epoch 00055: val_acc did not improve from 0.71231
# Epoch 56/100
#  - 37s - loss: 0.6610 - acc: 0.8584 - val_loss: 1.6169 - val_acc: 0.6800
#
# Epoch 00056: val_acc did not improve from 0.71231
# Epoch 57/100
#  - 37s - loss: 0.6538 - acc: 0.8613 - val_loss: 2.7813 - val_acc: 0.6158
#
# Epoch 00057: val_acc did not improve from 0.71231
# Epoch 58/100
#  - 37s - loss: 0.6531 - acc: 0.8655 - val_loss: 2.2552 - val_acc: 0.6277
#
# Epoch 00058: val_acc did not improve from 0.71231
# Epoch 59/100
#  - 37s - loss: 0.6546 - acc: 0.8649 - val_loss: 1.8510 - val_acc: 0.6605
#
# Epoch 00059: val_acc did not improve from 0.71231
# Epoch 60/100
#  - 36s - loss: 0.6521 - acc: 0.8639 - val_loss: 1.8785 - val_acc: 0.6576
#
# Epoch 00060: val_acc did not improve from 0.71231
# Epoch 61/100
#  - 37s - loss: 0.6537 - acc: 0.8633 - val_loss: 1.9649 - val_acc: 0.6471
#
# Epoch 00061: val_acc did not improve from 0.71231
# Epoch 62/100
#  - 37s - loss: 0.6478 - acc: 0.8634 - val_loss: 1.6395 - val_acc: 0.6863
#
# Epoch 00062: val_acc did not improve from 0.71231
# Epoch 63/100
#  - 37s - loss: 0.6509 - acc: 0.8632 - val_loss: 1.9028 - val_acc: 0.6664
# Epoch 00063: val_acc did not improve from 0.71231
# Epoch 64/100
#  - 37s - loss: 0.6436 - acc: 0.8658 - val_loss: 1.8585 - val_acc: 0.6769
#
# Epoch 00064: val_acc did not improve from 0.71231
# Epoch 65/100
#  - 37s - loss: 0.6479 - acc: 0.8631 - val_loss: 1.6822 - val_acc: 0.6949
#
# Epoch 00065: val_acc did not improve from 0.71231
# Epoch 66/100
#  - 37s - loss: 0.6450 - acc: 0.8635 - val_loss: 1.7699 - val_acc: 0.6901
#
# Epoch 00066: val_acc did not improve from 0.71231
# Epoch 67/100
#  - 37s - loss: 0.6398 - acc: 0.8706 - val_loss: 1.8009 - val_acc: 0.6767
#
# Epoch 00067: val_acc did not improve from 0.71231
# Epoch 68/100
#  - 37s - loss: 0.6452 - acc: 0.8658 - val_loss: 1.6348 - val_acc: 0.6803
#
# Epoch 00068: val_acc did not improve from 0.71231
# Epoch 69/100
#  - 37s - loss: 0.6414 - acc: 0.8684 - val_loss: 2.7352 - val_acc: 0.4906
#
# Epoch 00069: val_acc did not improve from 0.71231
# Epoch 70/100
#  - 37s - loss: 0.6415 - acc: 0.8705 - val_loss: 1.5977 - val_acc: 0.7011
#
# Epoch 00070: val_acc did not improve from 0.71231
# Epoch 71/100
#  - 37s - loss: 0.6371 - acc: 0.8703 - val_loss: 1.9355 - val_acc: 0.6440
#
# Epoch 00071: val_acc did not improve from 0.71231
# Epoch 72/100
#  - 37s - loss: 0.6380 - acc: 0.8677 - val_loss: 1.9938 - val_acc: 0.6432
#
# Epoch 00072: val_acc did not improve from 0.71231
# Epoch 73/100
#  - 36s - loss: 0.6359 - acc: 0.8699 - val_loss: 2.4262 - val_acc: 0.5847
#
# Epoch 00073: val_acc did not improve from 0.71231
# Epoch 74/100
#  - 37s - loss: 0.6396 - acc: 0.8722 - val_loss: 1.7623 - val_acc: 0.6626
#
# Epoch 00074: val_acc did not improve from 0.71231
# Epoch 75/100
#  - 37s - loss: 0.6329 - acc: 0.8718 - val_loss: 1.9073 - val_acc: 0.6743
#
# Epoch 00075: val_acc did not improve from 0.71231
# Epoch 76/100
#  - 37s - loss: 0.6296 - acc: 0.8765 - val_loss: 2.4661 - val_acc: 0.6705
#
# Epoch 00076: val_acc did not improve from 0.71231
# Epoch 77/100
#  - 37s - loss: 0.6331 - acc: 0.8715 - val_loss: 1.7924 - val_acc: 0.6521
#
# Epoch 00077: val_acc did not improve from 0.71231
# Epoch 78/100
#  - 37s - loss: 0.6310 - acc: 0.8727 - val_loss: 1.6740 - val_acc: 0.6853
#
# Epoch 00078: val_acc did not improve from 0.71231
# Epoch 79/100
#  - 37s - loss: 0.6278 - acc: 0.8726 - val_loss: 2.3519 - val_acc: 0.6301
#
# Epoch 00079: val_acc did not improve from 0.71231
# Epoch 80/100
#  - 37s - loss: 0.6245 - acc: 0.8759 - val_loss: 2.0275 - val_acc: 0.6889
#
# Epoch 00080: val_acc did not improve from 0.71231
# Epoch 81/100
#  - 37s - loss: 0.6263 - acc: 0.8751 - val_loss: 2.2967 - val_acc: 0.6337
#
# Epoch 00081: val_acc did not improve from 0.71231
# Epoch 82/100
#  - 37s - loss: 0.6293 - acc: 0.8729 - val_loss: 2.3190 - val_acc: 0.6268
#
# Epoch 00082: val_acc did not improve from 0.71231
# Epoch 83/100
#  - 37s - loss: 0.6272 - acc: 0.8747 - val_loss: 2.1842 - val_acc: 0.6406
#
# Epoch 00083: val_acc did not improve from 0.71231
# Epoch 84/100
#  - 37s - loss: 0.6270 - acc: 0.8776 - val_loss: 1.9854 - val_acc: 0.6846
#
# Epoch 00084: val_acc did not improve from 0.71231
# Epoch 85/100
#  - 37s - loss: 0.6233 - acc: 0.8742 - val_loss: 1.9497 - val_acc: 0.6263
#
# Epoch 00085: val_acc did not improve from 0.71231
# Epoch 86/100
#  - 37s - loss: 0.6257 - acc: 0.8731 - val_loss: 1.8628 - val_acc: 0.6468
#
# Epoch 00086: val_acc did not improve from 0.71231
# Epoch 87/100
#  - 37s - loss: 0.6229 - acc: 0.8744 - val_loss: 2.1456 - val_acc: 0.6530
#
# Epoch 00087: val_acc did not improve from 0.71231
# Epoch 88/100
#  - 37s - loss: 0.6235 - acc: 0.8731 - val_loss: 2.0426 - val_acc: 0.6432
#
# Epoch 00088: val_acc did not improve from 0.71231
# Epoch 89/100
#  - 37s - loss: 0.6197 - acc: 0.8780 - val_loss: 1.9497 - val_acc: 0.6719
#
# Epoch 00089: val_acc did not improve from 0.71231
# Epoch 90/100
#  - 37s - loss: 0.6206 - acc: 0.8791 - val_loss: 1.9460 - val_acc: 0.6724
#
# Epoch 00090: val_acc did not improve from 0.71231
# Epoch 91/100
#  - 37s - loss: 0.6203 - acc: 0.8768 - val_loss: 2.0180 - val_acc: 0.6738
#
# Epoch 00091: val_acc did not improve from 0.71231
# Epoch 92/100
#  - 36s - loss: 0.6194 - acc: 0.8782 - val_loss: 2.0965 - val_acc: 0.6800
#
# Epoch 00092: val_acc did not improve from 0.71231
# Epoch 93/100
#  - 36s - loss: 0.6208 - acc: 0.8805 - val_loss: 1.9968 - val_acc: 0.6700
#
# Epoch 00093: val_acc did not improve from 0.71231
# Epoch 94/100
#  - 37s - loss: 0.6175 - acc: 0.8804 - val_loss: 2.2286 - val_acc: 0.6182
#
# Epoch 00094: val_acc did not improve from 0.71231
# Epoch 95/100
#  - 37s - loss: 0.6124 - acc: 0.8813 - val_loss: 1.9858 - val_acc: 0.6698
#
# Epoch 00095: val_acc did not improve from 0.71231
# Epoch 96/100
#  - 37s - loss: 0.6153 - acc: 0.8816 - val_loss: 2.3112 - val_acc: 0.6559
#
# Epoch 00096: val_acc did not improve from 0.71231
# Epoch 97/100
#  - 37s - loss: 0.6199 - acc: 0.8811 - val_loss: 2.0490 - val_acc: 0.6442
#
# Epoch 00097: val_acc did not improve from 0.71231
# Epoch 98/100
#  - 37s - loss: 0.6145 - acc: 0.8793 - val_loss: 2.3931 - val_acc: 0.6459
#
# Epoch 00098: val_acc did not improve from 0.71231
# Epoch 99/100
#  - 37s - loss: 0.6160 - acc: 0.8826 - val_loss: 1.6409 - val_acc: 0.6815
#
# Epoch 00099: val_acc did not improve from 0.71231
# Epoch 100/100
#  - 37s - loss: 0.6130 - acc: 0.8809 - val_loss: 1.8010 - val_acc: 0.6703
#
# Epoch 00100: val_acc did not improve from 0.71231
# F1/Recall/Precision/Accuracy = 0.7114/0.7123/0.7299/0.7123
# Ensemble F1/Recall/Precision/Accuracy = 0.7379/0.7384/0.7601/0.7384
#
# # Summary
#               f1     recall  precision   accuracy
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.717617   0.729067   0.741649   0.729067
# std     0.049085   0.044819   0.050224   0.044819
# min     0.655331   0.675676   0.651156   0.675676
# 25%     0.678962   0.691636   0.711772   0.691636
# 50%     0.710366   0.719118   0.735831   0.719118
# 75%     0.758255   0.770630   0.788173   0.770630
# max     0.789636   0.793803   0.807573   0.793803
# Final acc =  0.7290674239988069

# %% [markdown]
# ## Visualization

# %%
from visualize import visualize_cam_audio
import random

offset = 0
X_train, y_train = project.vars.X_train, project.vars.y_train
model = project.vars.training_vars[0]
for j in range(5):
    i = random.randint(0, len(X_train))
    visualize_cam_audio(conf, model, X_train[offset+i], 'label:{}'.format(conf.labels[np.argmax(y_train[offset+i])]),
                  layer='last_conv')

# %%
X_test, y_test = project.vars.X_valid, project.vars.y_valid
for j in range(5):
    i = random.randint(0, len(X_test))
    visualize_cam_audio(conf, model, X_test[offset+i], 'label:{}'.format(conf.labels[np.argmax(y_test[offset+i])]),
                  layer='last_conv')
